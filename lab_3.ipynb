# %% [markdown]
# Владимир Кирилкин ПИ18-2
#
# ML 1.2. Регрессия на чистых данных
# https://docs.google.com/document/d/1qHuGZayaTBuzf1gyYe5cBSfADt31BiNO5IkJwFO2TPY/edit

# %%
import numpy as np
import pandas as pd
from pandas.plotting import scatter_matrix
from sklearn import linear_model
from sklearn.model_selection import train_test_split

X = pd.read_csv('data/8_x.csv')
Y = pd.read_csv('data/8_y.csv')

reg = linear_model.LinearRegression()
reg.fit(X, Y)
reg.coef_
# Out:
# array([[-1.86426141, 15.98409427,  1.82666643, 14.59413948,  6.31178558,
#         82.57346627, 95.09846873]])

# %%
reg.predict([[data['x1'][1], data['x2'][3], data['x3'][0]]])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-448495cff5a5> in <module>
# ----> 1 reg.predict([[data['x1'][1], data['x2'][3], data['x3'][0]]])
#       2
#
# NameError: name 'data' is not defined

# %%
reg.score(X, Y)
# Out:
# 0.9937215860437988

# %%
scatter_matrix(X);

# %%
X.describe()
# Out:
#        1.514584211013607  -0.6215632534883615  -1.2773786435188428  \
# count          82.000000            82.000000            82.000000
# mean            0.066293            -0.031786            -0.062652
# std             1.178463             0.945542             0.886621
# min            -3.545896            -1.889278            -2.538651
# 25%            -0.605097            -0.705903            -0.467983
# 50%             0.106223            -0.046640             0.030305
# 75%             0.794695             0.725357             0.566373
# max             2.470810             2.157520             1.884430
#
#        -1.2363403140287708  0.4496455440214159  -0.7133960667990855  \
# count            82.000000           82.000000            82.000000
# mean              0.219901            0.107702            -0.098748
# std               1.223936            1.025058             1.010925
# min              -2.502444           -2.621536            -2.452811
# ...

# %%
X.corr()
# Out:
#                        1.514584211013607  -0.6215632534883615  \
# 1.514584211013607               1.000000             0.106407
# -0.6215632534883615             0.106407             1.000000
# -1.2773786435188428            -0.044342            -0.061660
# -1.2363403140287708            -0.044396            -0.011577
# 0.4496455440214159             -0.012079            -0.071899
# -0.7133960667990855            -0.104582             0.007923
# -0.008099259430035137          -0.059200            -0.005232
#
#                        -1.2773786435188428  -1.2363403140287708  \
# 1.514584211013607                -0.044342            -0.044396
# -0.6215632534883615              -0.061660            -0.011577
# -1.2773786435188428               1.000000            -0.201572
# -1.2363403140287708              -0.201572             1.000000
# 0.4496455440214159                0.039562            -0.084220
# -0.7133960667990855               0.125219             0.013246
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
clf = linear_model.LinearRegression()
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.score(x_train,y_train)
# Out:
# 0.9943262365119807

# %%
clf.score(x_test,y_test)
# Out:
# 0.988100300189813
